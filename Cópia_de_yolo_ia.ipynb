# %% [markdown]
# Alunos:
#  - Marcos - 22352865
#  - Eduardo - 22353207
#  - Tiago Fonseca - 22407250

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.1 MB/s eta 0:00:00

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Inteligencia_Artificial/custom.yaml epochs=3 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Inteligencia_Artificial/custom.yaml epochs=150 imgsz=640
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo predict model=/content/runs/detect/train2/weights/best.pt source=/content/drive/MyDrive/Inteligencia_Artificial/val
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,768 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/4 /content/drive/MyDrive/Inteligencia_Artificial/val/Cópia de imgi_209_C_C-POP_bart.jpg: 416x640 1 bart, 34.0ms
# image 2/4 /content/drive/MyDrive/Inteligencia_Artificial/val/Cópia de imgi_212_os-simpsons-vai-acabar-maio-960x592.jpg: 416x640 1 bart, 6.8ms
# image 3/4 /content/drive/MyDrive/Inteligencia_Artificial/val/Cópia de imgi_215_temporada-35.jpg: 640x480 1 bart, 38.4ms
# image 4/4 /content/drive/MyDrive/Inteligencia_Artificial/val/Cópia de imgi_220_240716e9987b11d52bd1.jpg: 480x640 1 bart, 31.4ms
# Speed: 2.6ms preprocess, 27.6ms inference, 39.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=/content/runs/detect/train2/weights/best.pt source="/content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4"
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,008,768 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 33.9ms
# video 1/1 (frame 2/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 6.5ms
# video 1/1 (frame 3/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 6.1ms
# video 1/1 (frame 4/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 6.0ms
# video 1/1 (frame 5/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 6.1ms
# video 1/1 (frame 6/3151) /content/drive/MyDrive/Inteligencia_Artificial/videoplayback.mp4: 448x640 (no detections), 6.3ms
# ...

# %%
from pathlib import Path

import matplotlib.pyplot as plt
from PIL import Image


files = list(Path('/content/runs/detect/predict').glob('*.jpg'))

fig, axs = plt.subplots(2, 2, figsize=(16,16))
axs = [ax for row in axs for ax in row]

for file, ax in zip(files, axs):
    ax.imshow(Image.open(file))
    ax.axis('off')
